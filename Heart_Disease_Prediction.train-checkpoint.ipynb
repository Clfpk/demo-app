# %%
import pandas as pd
df=pd.read_csv("Heart_Disease_Prediction.csv")
df
# Out:
#       Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0    70.0    1                4  130        322.0             0            2
# 1    67.0    0                3  115        564.0             0            2
# 2    57.0    1                2  124        261.0             0            0
# 3    64.0    1                4  128        263.0             0            0
# 4    74.0    0                2  120        269.0             0            2
# ..    ...  ...              ...  ...          ...           ...          ...
# 265  52.0    1                3  172        199.0             1            0
# 266  44.0    1                2  120        263.0             0            0
# 267  56.0    0                2  140        294.0             0            2
# 268  57.0    1                4  140        192.0             0            0
# 269  67.0    1                4  160        286.0             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 0       109                0            2.4            2
# 1       160                0            1.6            2
# 2       141                0            0.3            1
# 3       105                1            0.2            2
# 4       121                1            0.2            1
# ..      ...              ...            ...          ...
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease
# 0                          3         3      Presence
# 1                          0         7       Absence
# 2                          0         7      Presence
# 3                          1         7       Absence
# 4                          1         3       Absence
# ..                       ...       ...           ...
# 265                        0         7       Absence
# 266                        0         7       Absence
# 267                        0         3       Absence
# 268                        0         6       Absence
# 269                        3         3      Presence
#
# [270 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# Age                        1
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                1
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              2
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
df=df.dropna()
df.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
df.dtypes
# Out:
# Age                        float64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                float64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease               object
# dtype: object

# %%
cclum=[]
for i in df.columns:
    if df[i].dtypes=="object":
        cclum.append(i)
print(cclum)
from sklearn import preprocessing
le = preprocessing.LabelEncoder()   
df[cclum]=df[cclum].apply(le.fit_transform)
df
# Out:
# ['Heart Disease']
# C:\Users\Prachi\AppData\Local\Temp\ipykernel_16320\2952230431.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[cclum]=df[cclum].apply(le.fit_transform)
#       Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0    70.0    1                4  130        322.0             0            2
# 1    67.0    0                3  115        564.0             0            2
# 2    57.0    1                2  124        261.0             0            0
# 3    64.0    1                4  128        263.0             0            0
# 4    74.0    0                2  120        269.0             0            2
# ..    ...  ...              ...  ...          ...           ...          ...
# 265  52.0    1                3  172        199.0             1            0
# 266  44.0    1                2  120        263.0             0            0
# 267  56.0    0                2  140        294.0             0            2
# 268  57.0    1                4  140        192.0             0            0
# 269  67.0    1                4  160        286.0             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 0       109                0            2.4            2
# 1       160                0            1.6            2
# 2       141                0            0.3            1
# 3       105                1            0.2            2
# 4       121                1            0.2            1
# ..      ...              ...            ...          ...
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium  Heart Disease
# 0                          3         3              1
# 1                          0         7              0
# 2                          0         7              1
# 3                          1         7              0
# 4                          1         3              0
# ..                       ...       ...            ...
# 265                        0         7              0
# 266                        0         7              0
# 267                        0         3              0
# 268                        0         6              0
# 269                        3         3              1
#
# [266 rows x 14 columns]

# %%
x=df.drop(["Sex"],axis=1)
y=df["Sex"]
x=x.to_numpy()
x.shape
# Out:
# (266, 13)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (212, 13) (54, 13) (212,) (54,)

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import confusion_matrix,classification_report
names=["SVM","NB","KNN","DT","RF","ET"]
clfs=[SVC(),GaussianNB(),KNeighborsClassifier(),DecisionTreeClassifier(),RandomForestClassifier(),ExtraTreesClassifier()]
CLFF=[]
for name,clf in zip(names,clfs):
    print(name)
    clf.fit(X_train,y_train)
    y_pred=clf.predict(X_test)
    CLFF.append(clf)
    print(confusion_matrix(y_test,y_pred))
    print(classification_report(y_test,y_pred))
    print('-----------------------------------------------')
# Out:
# SVM
# [[ 0 16]
#  [ 0 38]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        16
#            1       0.70      1.00      0.83        38
#
#     accuracy                           0.70        54
#    macro avg       0.35      0.50      0.41        54
# weighted avg       0.50      0.70      0.58        54
#
# -----------------------------------------------
# NB
# [[11  5]
#  [14 24]]
#               precision    recall  f1-score   support
#
#            0       0.44      0.69      0.54        16
#            1       0.83      0.63      0.72        38
#
#     accuracy                           0.65        54
#    macro avg       0.63      0.66      0.63        54
# weighted avg       0.71      0.65      0.66        54
#
# -----------------------------------------------
# KNN
# [[ 5 11]
#  [ 5 33]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.31      0.38        16
#            1       0.75      0.87      0.80        38
#
#     accuracy                           0.70        54
#    macro avg       0.62      0.59      0.59        54
# weighted avg       0.68      0.70      0.68        54
#
# -----------------------------------------------
# DT
# [[ 7  9]
#  [15 23]]
#               precision    recall  f1-score   support
#
#            0       0.32      0.44      0.37        16
#            1       0.72      0.61      0.66        38
#
#     accuracy                           0.56        54
#    macro avg       0.52      0.52      0.51        54
# weighted avg       0.60      0.56      0.57        54
#
# -----------------------------------------------
# RF
# [[ 8  8]
#  [ 5 33]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.50      0.55        16
#            1       0.80      0.87      0.84        38
#
#     accuracy                           0.76        54
#    macro avg       0.71      0.68      0.69        54
# weighted avg       0.75      0.76      0.75        54
#
# -----------------------------------------------
# ET
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [[10  6]
#  [ 7 31]]
#               precision    recall  f1-score   support
#
#            0       0.59      0.62      0.61        16
#            1       0.84      0.82      0.83        38
#
#     accuracy                           0.76        54
#    macro avg       0.71      0.72      0.72        54
# weighted avg       0.76      0.76      0.76        54
#
# -----------------------------------------------

# %%
import pickle
pickle.dump(CLFF,open("Heart_Disease_Prediction.pkl","wb"))
